# %% [markdown]
# <a href="https://colab.research.google.com/github/palpitation0/ML-lecture-code/blob/master/Tree_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree
from sklearn import datasets
iris = datasets.load_iris()

# %%
dir(iris)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
clf = tree.DecisionTreeClassifier()
clf2 = clf.fit(iris.data, iris.target)

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf2, out_file=None)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# # **Regression Tree**

# %%
X = [[0,0],[2,2]]
y = [0.5, 2.5]
rclf = tree.DecisionTreeRegressor()
rclf = rclf.fit(X,y)

# %%
X_test = [[0.1,0.1],[0.5,0.5],[1.0,1.0],[1.5,1.5],[2.5,2.5]]
y_test = rclf.predict(X_test)
y_test
# Out:
# array([0.5, 0.5, 0.5, 2.5, 2.5])

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# %%
rng = np.random.RandomState(1)
X = np.sort(5*rng.rand(80,1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3*(0.5 - rng.rand(16))

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X,y)
regr_2.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %%
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black", label="data")
plt.plot(X_test, y_1, color="blue", label="max_depth=2")
plt.plot(X_test, y_2, color="orange", label="max_depth=5")
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
